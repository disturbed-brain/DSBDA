# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["age"] = df["age"].fillna(df["age"].mean())
df["embark_town"] = df["age"].ffill()
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.boxplot(data=df, x="sex", y="age", hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df['embarked'] = df['embarked'].fillna('Unknown')

# Step 3: Create separate encoders
encoder_sex = LabelEncoder()
encoder_embarked = LabelEncoder()

# Step 4: Apply encoding
df["sex_enc"] = encoder_sex.fit_transform(df["sex"])
df["embarked_enc"] = encoder_embarked.fit_transform(df["embarked"])

# Step 5: Check result
print(df[['sex', 'sex_enc', 'embarked', 'embarked_enc']].head())
# Out:
#       sex  sex_enc embarked  embarked_enc
# 0    male        1        S             2
# 1  female        0        C             0
# 2  female        0        S             2
# 3  female        0        S             2
# 4    male        1        S             2

# %%
from sklearn.preprocessing import LabelEncoder
sex_encoder = LabelEncoder()
df["sex_enc"] = sex_encoder.fit_transform(df["sex"])
embarked_encoder = LabelEncoder()
df["embarked_enc"] = embarked_encoder.fit_transform(df["embarked"])

# %%
sns.heatmap(df.drop(["alive","alone","who","adult_male","sex","class","deck","embarked","embark_town"], axis=1).corr(), annot=True)
# Out:
# <Axes: >
